# %%
import test_sgld_v7
# test_sgld_v7.test_stgp_linear(in_feature=6)
test_sgld_v7.test_stgp_2D(5)
# test_sgld_v7.test_significant_voxels()
# Out:
# Simulated 1000 images of 5×5 = 25 pixels
# Epoch 1/300
# Epoch 101/300
# Epoch 201/300
# Threshold δ=1.000, selecting r=0 voxels at FDR=0.05
# predict (sample_avg)::variance_prediction=[[0.1131321]]
# Y(predicted)=tensor([[0.0861]]) Y(expected)=13.999441707220498
